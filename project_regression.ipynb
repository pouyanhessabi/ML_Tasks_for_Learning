# %% [markdown]
# <a href="https://colab.research.google.com/github/pouyanhessabi/ML_Tasks_for_Learning/blob/main/project_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ✅ **Introduction:**
# This project is given by ChatGPT for the Supervised Machine Learning: Regression and Classification Course.
#
# # **ChatGPT Prompt**:
# *I am working on the "Supervised Machine Learning: Regression and Classification" course by DeepLearning.AI and Stanford Online on the Coursera. Please search on this website to gain more information about this course: https://www.coursera.org/learn/machine-learning. <br>
# These are the objectives of the course: <br>
# Build machine learning models in Python using popular machine learning libraries NumPy and scikit-learn.
# Build and train supervised machine learning models for prediction and binary classification tasks, including linear regression and logistic regression
# And you can find the specific topics in the Coursera website.
# <br>
# Focusing on the topics in the course, I want you to design a mini-project (which takes 2 days to accomplish) based on the topics in order to enhance my skills. The project should cover course material and verify my skills in this field. Consider I have hands-on experience in programming using Python. Make The Timeline in 2 days and give me deadlines*
# # **ChatGPT Response (project definition)**:
# ### Mini-Project: **Predicting House Prices and Classification of Loan Default Risk**
#
# #### Objective:
# 1. Build a regression model to predict house prices using linear regression.
# 2. Build a binary classification model to predict the likelihood of loan default using logistic regression.
# 3. Use NumPy and scikit-learn libraries for implementation.
#
# ---
#
# ### Day 1: Regression Task - House Price Prediction
# #### **Goal**: Apply linear regression to predict house prices using a dataset with numerical and categorical features.
#
# #### **Timeline:**
# - **Morning (3 hours)**:
#   1. **Dataset Preparation**:
#      - Download a dataset (e.g., *California Housing Dataset* from `sklearn` or another housing dataset).
#      - Explore and preprocess the data (e.g., handle missing values, normalize numerical data, encode categorical data).
#
#   2. **Feature Engineering**:
#      - Select key features for predicting house prices (e.g., square footage, number of bedrooms, location).
#
# - **Afternoon (3 hours)**:
#   3. **Model Building**:
#      - Split the data into training and testing sets.
#      - Build a linear regression model using `sklearn.linear_model.LinearRegression`.
#      - Train the model and evaluate it using Mean Absolute Error (MAE) and R-squared metrics.
#
#   4. **Visualization**:
#      - Plot predictions vs. actual house prices for the test set.
#      - Visualize residual errors to assess model performance.
#
# ---
#
# ### Day 2: Classification Task - Loan Default Risk
# #### **Goal**: Apply logistic regression to classify whether a borrower will default on a loan.
#
# #### **Timeline**:
# - **Morning (3 hours)**:
#   1. **Dataset Preparation**:
#      - Use the *Loan Default Dataset* (search for a suitable dataset on Kaggle or generate synthetic data with features like income, loan amount, and credit score).
#      - Explore and preprocess the data (e.g., handle missing values, scale numerical features).
#
#   2. **Feature Selection**:
#      - Choose relevant features (e.g., income-to-loan ratio, credit score).
#
# - **Afternoon (3 hours)**:
#   3. **Model Building**:
#      - Split the data into training and testing sets.
#      - Build a logistic regression model using `sklearn.linear_model.LogisticRegression`.
#      - Train the model and evaluate using metrics like accuracy, precision, recall, and ROC-AUC.
#
#   4. **Model Interpretation**:
#      - Analyze coefficients to understand feature importance.
#      - Plot the ROC curve to evaluate classification performance.
#
# ---
#
# ### Deliverables:
# 1. **Day 1**:
#    - A Python script or Jupyter Notebook for the regression task.
#    - Evaluation metrics and visualizations for the regression model.
#
# 2. **Day 2**:
#    - A Python script or Jupyter Notebook for the classification task.
#    - Evaluation metrics and ROC curve for the classification model.
#
# ---
#
# ### Tools and Libraries:
# - **NumPy**: Data manipulation.
# - **pandas**: Data preprocessing.
# - **scikit-learn**: Model building and evaluation.
# - **matplotlib/seaborn**: Visualization.
#
# Let me know if you want further guidance!

# %% [markdown]
# # ✅ **Pre-processing**
# *   Dataset Selection
# *   Data Loading
# *   Exploratory Data Analysis (EDA)
# *   Preprocessing
# *   Feature Engineering

# %% [markdown]
# ## **Dataset Selection** and **Load Data**

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

data = fetch_california_housing(as_frame=True)
df = data.frame

# %% [markdown]
# ## **Exploratory Data Analysis (EDA)**

# %% [markdown]
# ### Pandas Functions:
# ```
# df.info()
# df.head()
# df.shape()
# df.describe()
# df.isnull().sum()
# ```

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
print(df.shape)
# Out:
# (20640, 9)

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# min        0.692308     32.540000   -124.350000      0.149990
# 25%        2.429741     33.930000   -121.800000      1.196000
# 50%        2.818116     34.260000   -118.490000      1.797000
# 75%        3.282261     37.710000   -118.010000      2.647250
# max     1243.333333     41.950000   -114.310000      5.000010

# %%
df.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %% [markdown]
# ### Univarient
#  histograms for numerical features and  bar plots for categorical features

# %%
import matplotlib.pyplot as plt

for feature in df.columns:
  plt.title(feature)
  plt.xlabel("Value")
  plt.ylabel("Frequency")
  df[feature].hist(bins=50, figsize=(5,3))
  min = df[feature].min()
  max = df[feature].max()
  plt.xlim([min, max])
  plt.show()

# %%
import seaborn as sns
# for feature in df.columns:
#   plt.title(feature)
#   plt.xlabel("Value")
#   plt.ylabel("Frequency")
#   sns.boxplot(x=df[feature])
#   print(df[feature].describe())
#   min = df[feature].min()
#   max = df[feature].max()
#   plt.xlim([min, max])
#   # plt.show()

sns.boxplot(x=df[df.columns[0]])
# Out:
# <Axes: xlabel='MedInc'>

# %%
sns.boxplot(x=df[df.columns[1]])
# Out:
# <Axes: xlabel='HouseAge'>

# %%
sns.boxplot(x=df[df.columns[2]])
# Out:
# <Axes: xlabel='AveRooms'>

# %% [markdown]
# ### Multivariate Analysis
#
# Using Scatterplots and Correlation Heatmaps Together: <br>
#
#
# *   Start with a Heatmap: Identify pairs of variables with high correlations (positive or negative).
# *   Dive Deeper with Scatterplots: For the most correlated pairs, create scatterplots to understand the nature of the relationship (e.g., linear, curvilinear, outliers).
# *   Insights for Feature Engineering:
#     -   Highly correlated features may indicate redundancy; consider dropping one of the features or combining them.
#     - Weakly correlated features with the target variable may have limited predictive power.

# %%
target_feature = df.columns[-1]
target_feature
# Out:
# 'MedHouseVal'

# %%
for feature in df.columns[:-1]:
  plt.scatter(df[feature], df[target_feature])
  plt.xlabel(feature)
  plt.ylabel(target_feature)
  plt.show()

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## **Preprocess Technical**
# * Handling Missing Values
# * Encoding Categorical Variables
# * Scaling Numerical Features
# * Removing Outliers
# * Splitting Data into training and testing

# %% [markdown]
# ### Handling Missing Values

# %%
for feature in df.columns:
  df[feature].fillna(df[feature].mean(), inplace=True)
# Out:
# <ipython-input-71-70714cc1359f>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[feature].fillna(df[feature].mean(), inplace=True)

# %% [markdown]
# ### Encoding Categorical Feature
#
# Convert categorical features into numerical representations:
# * One-hot encoding
# * Label encoding

# %% [markdown]
# ### Scaling Numerical Features
# Normalize or standardize numerical features to ensure consistent ranges

# %% [markdown]
# ### Removing Outliers
# IQR rule: Interquartile Range

# %%
Q1 = df[df.columns[0]].quantile(0.25)
Q3 = df[df.columns[0]].quantile(0.75)
IQR = Q3 - Q1
df_copy = df[~((df[df.columns[0]] < (Q1 - 1.5 * IQR)) | (df[df.columns[0]] > (Q3 + 1.5 * IQR)))].copy()
print(f"Before removing outliers: {df.shape}")
print(f"After removing outliers: {df_copy.shape}")
print(f"Q1: {Q1}")
print(f"Q3: {Q3}")
print(f"IQR: {IQR}")
sns.boxplot(x=df[df.columns[0]])
print(df[df.columns[0]].describe())
# Out:
# Before removing outliers: (20640, 9)
# After removing outliers: (19959, 9)
# Q1: 2.5633999999999997
# Q3: 4.74325
# IQR: 2.17985
# count    20640.000000
# mean         3.870671
# std          1.899822
# min          0.499900
# 25%          2.563400
# 50%          3.534800
# 75%          4.743250
# max         15.000100
# Name: MedInc, dtype: float64

# %%
sns.boxplot(x=df_copy[df_copy.columns[0]])
print(df_copy[df.columns[0]].describe())
# Out:
# count    19959.000000
# mean         3.657296
# std          1.488482
# min          0.499900
# 25%          2.536900
# 50%          3.469800
# 75%          4.593800
# max          8.011300
# Name: MedInc, dtype: float64

# %% [markdown]
# ##**Feature Engineering**
# * Creating New Features
# * Selecting Relevant Features
# * Polynomial Features
# * Binning Continuous Variables
# * Removing Low-Variance Features
# * Principal Component Analysis (PCA)

# %% [markdown]
# ## **Splitting Data**

# %%
from sklearn.model_selection import train_test_split

x = df.drop(df.columns[:-1], axis=1)
y = df[df.columns[-1]]
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # ✅ **Model Building and Training**

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_train_pred = model.predict(X_train)
mse_train = mean_squared_error(y_train, y_train_pred)
r2_train = r2_score(y_train, y_train_pred)
print("Training MSE:", mse_train)
print("Training R²:", r2_train)
# Out:
# Training MSE: 2.085533457130786e-31
# Training R²: 1.0

# %% [markdown]
# # ✅ **Model Evaluation**

# %%
y_test_pred = model.predict(X_test)
mse_test = mean_squared_error(y_test, y_test_pred)
r2_test = r2_score(y_test, y_test_pred)
print("Training MSE:", mse_train)
print("Testing MSE:", mse_test)
print("Training R²:", r2_train)
print("Testing R²:", r2_test)
# Out:
# Training MSE: 2.085533457130786e-31
# Testing MSE: 2.077766752725695e-31
# Training R²: 1.0
# Testing R²: 1.0

# %%
import matplotlib.pyplot as plt

residuals = y_test - y_test_pred
plt.scatter(y_test_pred, residuals)
plt.xlabel("Predicted Prices")
plt.ylabel("Residuals")
plt.title("Residual Analysis")
plt.show()

# %%
plt.scatter(y_test, y_test_pred, alpha=0.1)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs Predicted Prices")
plt.show()

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=5)
print("Average MSE:", -scores.mean())
# Out:
# Average MSE: 8.424107780114091e-32
